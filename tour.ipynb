# %%
# 관광지 추천 하기 만들기
while True :
    
    x = input("원하는 도시를 입력 해 주세요 >")
    if x == "강릉" :
        print("강릉은 강원도에 위치 하여 있고 바다가 있는 대표적 휴양지로 경기도 시흥 기준 차량으로 226km 2시간 48분 가량 걸립니다.")
        print("주요 관광지로는 안목 카페 거리 , 오죽헌 , 경포대 , 또 한 북쪽으로는 주문진 , 남쪽으로는 정동진이 있으며 ")
        print("주변 도시로는 북쪽으로는 양양 , 속초 , 고성이 , 남쪽으로는 동해 , 삼척이 있습니다. ")
    if x == "속초" :
        print("속초는 강원도에 위치 하여 있고 바다가 있는 대표적 휴양지로 경기도 시흥 기준 차량으로 236km 3시간 26분 가량 걸립니다.")
        print("주요 관광지로는 속초아이 , 청초호 , 속초 중앙 시장 , 또 한 남쪽으로는 주문진이 있으며 ")
        print("주변 도시로는 남쪽으로는 양양 , 강릉 북쪽으로는 고성이 있습니다. ")
    if x == "양양" :
        print("양양은 강원도에 위치 하여 있고 바다가 있는 대표적 휴양지로 최근 서퍼들의 성지로 각광을 받으며 게스트하우스 파티가 유명합니다.")
        print("경기도 시흥 기준 차량으로 213km 2시간 40분 가량 걸립니다.")
        print("주요 관광지로는 낙산사 , 하조대 , 양양 해수욕장 , 서피 비치 등이 있으며 북쪽에는 속초가 위치 하고 있습니다.")
        
    if x == "그만" :
        print("프로그램을 종료 합니다.")
        break
# Out:
# 원하는 도시를 입력 해 주세요 >강릉
# 강릉은 강원도에 위치 하여 있고 바다가 있는 대표적 휴양지로 경기도 시흥 기준 차량으로 226km 2시간 48분 가량 걸립니다.
# 주요 관광지로는 안목 카페 거리 , 오죽헌 , 경포대 , 또 한 북쪽으로는 주문진 , 남쪽으로는 정동진이 있으며
# 주변 도시로는 북쪽으로는 양양 , 속초 , 고성이 , 남쪽으로는 동해 , 삼척이 있습니다.
# 원하는 도시를 입력 해 주세요 >양양
# 양양은 강원도에 위치 하여 있고 바다가 있는 대표적 휴양지로 최근 서퍼들의 성지로 각광을 받으며 게스트하우스 파티가 유명합니다.
# 경기도 시흥 기준 차량으로 213km 2시간 40분 가량 걸립니다.
# 주요 관광지로는 낙산사 , 하조대 , 양양 해수욕장 , 서피 비치 등이 있으며 북쪽에는 속초가 위치 하고 있습니다.
# 원하는 도시를 입력 해 주세요 >그만
# 프로그램을 종료 합니다.
