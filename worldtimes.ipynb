# %%
from datetime import datetime,timedelta
korea = datetime.now()
a = korea - timedelta(hours = 8)
while True :
    
    x = input("시간을 알고 싶은 나라를 입력 해 주세요 >")
    if x == "한국" or "대한민국" or "서울":
        print(f'한국 서울의 시간은 현재 {korea} 입니다. ')
    if x == "일본" or "도쿄" or "동경":
        print(f'일본 도쿄의 시간은 현재 {korea} 입니다. ')
    if x == "영국" or "런던" :
        print(f'영국 런던의 시간은 현재 {a} 입니다. ')

# %%
from datetime import datetime , timedelta
korea = datetime.now() #한국 일본 시간
london = korea - timedelta ( hours = 8) #런던 리스본 시간
rome = korea - timedelta (hours = 7) # 로마 베를린 파리 마드리드 케이프타운 아테네 헬싱키 시간
mos = korea - timedelta (hours = 6) #모스크바 이스탄불 바그다드
dub = korea - timedelta (hours = 5) # 아부다비 두바이
pak = korea - timedelta (hours = 4) # 파키스탄
ban = korea - timedelta (hours = 3) # 방글라데시 카자흐스탄
vit = korea - timedelta (hours = 2) # 베트남 태국 인도네시아
beg = korea - timedelta (hours = 1) # 싱가포르 베이징 대만
aus = korea + timedelta (hours = 2) # 시드니 캔버라
new = korea + timedelta (hours = 3) # 뉴질랜드 피지
haw = korea + timedelta (hours = 5) # 하와이
als = korea + timedelta (hours = 7) # 알래스카
la = korea + timedelta (hours = 8) # 시애틀 샌프란 la  밴쿠버 (캐나다)
den = korea + timedelta (hours = 9) # 미국 덴버 캐나다 에드먼턴
chi = korea + timedelta (hours = 10) # 미국 시카고
ny = korea + timedelta (hours = 11) # 미국 뉴욕 워싱턴 캐나다 몬트리올 오타와 베네수엘라 볼리비아
bra = korea + timedelta (hours = 12) # 브라질 아르헨티나

while True :
    x = input ("시간을 알고 싶은 나라를 입력 해 주세요 >")
    if x == '한국':
        print(f'한국 서울의 시간은 현재 {korea} 입니다. ')
    elif x == '대한민국' :
        print(f'한국 서울의 시간은 현재 {korea} 입니다. ')
    elif x == '서울' :
        print(f'한국 서울의 시간은 현재 {korea} 입니다. ')
    elif x == '일본' :
        print(f'일본 도쿄의 시간은 현재 {korea} 입니다. ')
    elif x == '도쿄' :
        print(f'일본 도쿄의 시간은 현재 {korea} 입니다. ')
    elif x == '동경' :
        print(f'일본 도쿄의 시간은 현재 {korea} 입니다. ')
    elif x == '런던' :
        print(f'영국 런던의 시간은 현재 {london} 입니다.')
    elif x == '영국' :
        print(f'영국 런던의 시간은 현재 {london} 입니다.')
    elif x == '포르투갈':
        print(f'포르투갈 리스본의 시간은 현재 {london} 입니다.')
    elif x == '리스본':
        print(f'포르투갈 리스본의 시간은 현재 {london} 입니다.')
    elif x == '로마':
        print(f'이탈리아 로마의 시간은 현재 {rome} 입니다.')
    elif x == '이탈리아':
        print(f'이탈리아 로마의 시간은 현재 {rome} 입니다.')
    elif x == '독일':
        print(f'독일 베를린의 시간은 현재 {rome} 입니다.')
    elif x == '베를린':
        print(f'독일 베를린의 시간은 현재 {rome} 입니다.')
    elif x == '프랑스':
        print(f'프랑스 파리의 시간은 현재 {rome} 입니다.')
    elif x == '파리':
        print(f'프랑스 파리의 시간은 현재 {rome} 입니다.')
    elif x == '마드리드':
        print(f'스페인 마드리드의 시간은 현재 {rome} 입니다.')
    elif x == '스페인':
        print(f'스페인 마드리드의 시간은 현재 {rome} 입니다.')
    elif x == '남아프리카 공화국':
        print(f'남아프리카 공화국 케이프타운의 시간은 현재 {rome} 입니다.')
    elif x == '남아공':
        print(f'남아프리카 공화국 케이프타운의 시간은 현재 {rome} 입니다.')
    elif x == '케이프타운':
        print(f'남아프리카 공화국 케이프타운의 시간은 현재 {rome} 입니다.')
    elif x == '아테네':
        print(f'그리스 아테네의 시간은 현재 {rome} 입니다.')
    elif x == '그리스':
        print(f'그리스 아테네의 시간은 현재 {rome} 입니다.')
    elif x == '핀란드':
        print(f'핀란드 헬싱키의 시간은 현재 {rome} 입니다.')
    elif x == '헬싱키':
        print(f'핀란드 헬싱키의 시간은 현재 {rome} 입니다.')
    elif x == '러시아':
        print(f'러시아 모스크바의 시간은 현재 {mos} 입니다.')
    elif x == '모스크바':
        print(f'러시아 모스크바의 시간은 현재 {mos} 입니다.')
    elif x == '이라크':
        print(f'이라크 바그다드의 시간은 현재 {mos} 입니다.')
    elif x == '바그다드':
        print(f'이라크 바그다드의 시간은 현재 {mos} 입니다.')
    elif x == '터키':
        print(f'튀르키예 이스탄불의 시간은 현재 {mos} 입니다.')
    elif x == '튀르키예':
        print(f'튀르키예 이스탄불의 시간은 현재 {mos} 입니다.')
    elif x == '이스탄불':
        print(f'튀르키예 이스탄불의 시간은 현재 {mos} 입니다.')
    elif x == '아부다비':
        print(f'아랍에미리트 아부다비의 시간은 현재 {dub} 입니다.')
    elif x == '아랍에미리트':
        print(f'아랍에미리트 아부다비의 시간은 현재 {dub} 입니다.')
    elif x == '두바이':
        print(f'아랍에미리트 두바이의 시간은 현재 {dub} 입니다.')
    elif x == '파키스탄':
        print(f'파키스탄 이슬라마바드의 시간은 현재 {pak} 입니다.')
    elif x == '방글라데시':
        print(f'방글라데시 다카의 시간은 현재 {ban} 입니다.')
    elif x == '다카':
        print(f'방글라데시 다카의 시간은 현재 {ban} 입니다.')
    elif x == '아스타나':
        print(f'카자흐스탄 아스타나의 시간은 현재 {ban} 입니다.') 
    elif x == '카자흐스탄':
        print(f'카자흐스탄 아스타나의 시간은 현재 {ban} 입니다.') 
    elif x == '베트남':
        print(f'베트남 하노이의 시간은 현재 {vit} 입니다.') 
    elif x == '하노이':
        print(f'베트남 하노이의 시간은 현재 {vit} 입니다.') 
    elif x == '태국':
        print(f'태국 방콕의 시간은 현재 {vit} 입니다.') 
    elif x == '방콕':
        print(f'태국 방콕의 시간은 현재 {vit} 입니다.')
    elif x == '타이':
        print(f'태국 방콕의 시간은 현재 {vit} 입니다.')
    elif x == '인도네시아':
        print(f'인도네시아 자카르타의 시간은 현재 {vit} 입니다.') 
    elif x == '자카르타':
        print(f'인도네시아 자카르타의 시간은 현재 {vit} 입니다.') 
    elif x == '싱가포르':
        print(f'싱가폴 싱가폴의 시간은 현재 {vit} 입니다.') 
    elif x == '싱가폴':
        print(f'싱가폴 싱가폴의 시간은 현재 {vit} 입니다.') 
    elif x == '베이징':
        print(f'중국 베이징의 시간은 현재 {vit} 입니다.') 
    elif x == '중국':
        print(f'중국 베이징의 시간은 현재 {vit} 입니다.') 
    elif x == '북경':
        print(f'중국 베이징의 시간은 현재 {vit} 입니다.') 
    elif x == '대만':
        print(f'대만 타이페이의 시간은 현재 {vit} 입니다.') 
    elif x == '타이페이':
        print(f'대만 타이페이의 시간은 현재 {vit} 입니다.') 
    elif x == '타이완':
        print(f'대만 타이페이의 시간은 현재 {vit} 입니다.') 
    elif x == '시드니':
        print(f'호주 시드니의 시간은 현재 {aus} 입니다.') 
    elif x == '호주':
        print(f'호주 시드니의 시간은 현재 {aus} 입니다.') 
    elif x == '오스트레일리아':
        print(f'호주 시드니의 시간은 현재 {aus} 입니다.') 
    elif x == '캔버라':
        print(f'호주 캔버라의 시간은 현재 {aus} 입니다.') 
    elif x == '뉴질랜드':
        print(f'뉴질랜드 웰링턴의 시간은 현재 {new} 입니다.') 
    elif x == '웰링턴':
        print(f'뉴질랜드 웰링턴의 시간은 현재 {new} 입니다.') 
    elif x == '하와이':
        print(f'미국 하와이의 시간은 현재 {haw} 입니다.') 
    elif x == '호놀룰루':
        print(f'미국 하와이의 시간은 현재 {haw} 입니다.') 
    elif x == '알래스카':
        print(f'미국 알래스카의 시간은 현재 {als} 입니다.') 
    elif x == '로스엔젤레스':
        print(f'미국 로스엔젤레스의 시간은 현재 {la} 입니다.')
    elif x == 'LA':
        print(f'미국 로스엔젤레스의 시간은 현재 {la} 입니다.')
    elif x == '샌프란시스코':
        print(f'미국 샌프란시스코의 시간은 현재 {la} 입니다.')
    elif x == '시애틀':
        print(f'미국 시애틀의 시간은 현재 {la} 입니다.')
    elif x == '벤쿠버':
        print(f'캐나다 벤쿠버의 시간은 현재 {la} 입니다.')
    elif x == '덴버':
        print(f'미국 덴버의 시간은 현재 {den} 입니다.') 
    elif x == '애드먼턴':
        print(f'캐나다 애드먼턴의 시간은 현재 {den} 입니다.')
    elif x == '시카고':
        print(f'미국 시카고의 시간은 현재 {chi} 입니다.')
    elif x == '뉴욕':
        print(f'미국 뉴욕의 시간은 현재 {ny} 입니다.')
    elif x == '워싱턴':
        print(f'미국 워싱턴의 시간은 현재 {ny} 입니다.')
    elif x == '몬트리올':
        print(f'캐나다 몬트리올의 시간은 현재 {ny} 입니다.')
    elif x == '오타와':
        print(f'캐나다 몬트리올의 시간은 현재 {ny} 입니다.')
    elif x == '베네수엘라':
        print(f'베네수엘라 카라카스의 시간은 현재 {ny} 입니다.')
    elif x == '카라카스':
        print(f'베네수엘라 카라카스의 시간은 현재 {ny} 입니다.')
    elif x == '볼리비아':
        print(f'볼리비아 라파스의 시간은 현재 {ny} 입니다.')
    elif x == '라파스':
        print(f'볼리비아 라파스의 시간은 현재 {ny} 입니다.')
    elif x == '브라질':
        print(f'브라질 브라질리아의 시간은 현재 {bra} 입니다.')
    elif x == '브라질리아':
        print(f'브라질 브라질리아의 시간은 현재 {bra} 입니다.')
    elif x == '아르헨티나':
        print(f'아르헨티나 부에노스아이레스의 시간은 현재 {bra} 입니다.')
    elif x == '부에노스아이레스':
        print(f'아르헨티나 부에노스아이레스의 시간은 현재 {bra} 입니다.')

    elif x == '종료' :
        print('프로그램을 종료합니다.')
        break
    else:
        print('입력을 잘 못 하셨습니다.')
# Out:
# 시간을 알고 싶은 나라를 입력 해 주세요 >영국
# 영국 런던의 시간은 현재 2023-10-21 11:52:08.626368 입니다.
# 시간을 알고 싶은 나라를 입력 해 주세요 >런던
# 영국 런던의 시간은 현재 2023-10-21 11:52:08.626368 입니다.
# 시간을 알고 싶은 나라를 입력 해 주세요 >호주
# 호주 시드니의 시간은 현재 2023-10-21 21:52:08.626368 입니다.
# 시간을 알고 싶은 나라를 입력 해 주세요 >캔버라
# 호주 캔버라의 시간은 현재 2023-10-21 21:52:08.626368 입니다.
# 시간을 알고 싶은 나라를 입력 해 주세요 >다카
# 방글라데시 다카의 시간은 현재 2023-10-21 16:52:08.626368 입니다.
# 시간을 알고 싶은 나라를 입력 해 주세요 >마드리드
# 스페인 마드리드의 시간은 현재 2023-10-21 12:52:08.626368 입니다.
# 시간을 알고 싶은 나라를 입력 해 주세요 >중국
# 중국 베이징의 시간은 현재 2023-10-21 17:52:08.626368 입니다.
# 시간을 알고 싶은 나라를 입력 해 주세요 >대만
# 대만 타이페이의 시간은 현재 2023-10-21 17:52:08.626368 입니다.
# 시간을 알고 싶은 나라를 입력 해 주세요 >베트남
# 베트남 하노이의 시간은 현재 2023-10-21 17:52:08.626368 입니다.
# 시간을 알고 싶은 나라를 입력 해 주세요 >싱가포르
# 싱가폴 싱가폴의 시간은 현재 2023-10-21 17:52:08.626368 입니다.
# 시간을 알고 싶은 나라를 입력 해 주세요 >서울
# 한국 서울의 시간은 현재 2023-10-21 19:52:08.626368 입니다.
# 시간을 알고 싶은 나라를 입력 해 주세요 >뉴욬
# 입력을 잘 못 하셨습니다.
# 시간을 알고 싶은 나라를 입력 해 주세요 >뉴욕
# 미국 뉴욕의 시간은 현재 2023-10-22 06:52:08.626368 입니다.
# ...
